# %%
# Import packages
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 72
import numpy as np
import pandas as pd
from collections import Counter
import torch
import torch.nn as nn
from torchvision import models
import seaborn as sns

Device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(f'PyTorch version= {torch.__version__}')
print(f'CUDA available= {torch.cuda.is_available()}')
# Out:
# PyTorch version= 2.3.1+cu118
# CUDA available= True

# %% [markdown]
# #### Exploring SemArt Dataset

# %%
df = pd.read_csv(r'.\\Data\\semart_train.csv', encoding = "ISO-8859-1", sep='\t')
df.head()
# Out:
#            IMAGE_FILE                                        DESCRIPTION  \
# 0   19873-1darmst.jpg  The Meyer or Darmstadt Madonna is the last, mo...
# 1  18759-guard301.jpg  Whereas Canaletto incorporates classically ins...
# 2  04589-temptati.jpg  In this painting the refinement of the colouri...
# 3      15104-magi.jpg  The left side of the painting was cut, origina...
# 4  36582-paolo_f1.jpg  The painting illustrates a famous episode from...
#
#                       AUTHOR  \
# 0  HOLBEIN, Hans the Younger
# 1          GUARDI, Francesco
# 2         BILIVERT, Giovanni
# 3     GEERTGEN tot Sint Jans
# 4              SCHEFFER, Ary
#
#                                                TITLE  \
# 0                                  Darmstadt Madonna
# 1                  Landscape with a Fisherman's Tent
# 2               The Temptation of Charles and Ubalde
# 3                              Adoration of the Magi
# 4  The Ghosts of Paolo and Francesca Appear to Da...
#
#                        TECHNIQUE                 DATE       TYPE  \
# 0  Oil on limewood, 147 x 102 cm  1526 and after 1528  religious
# 1      Oil on canvas, 49 x 77 cm              1770-75  landscape
# 2      Oil on copper, 37 x 28 cm              1629-30  religious
# 3             Panel, 111 x 69 cm              1480-85  religious
# 4    Oil on canvas, 167 x 234 cm                 1835      other
#
#           SCHOOL  TIMEFRAME
# 0         German  1501-1550
# 1        Italian  1751-1800
# 2        Italian  1601-1650
# 3  Netherlandish  1451-1500
# 4          Dutch  1801-1850

# %%
painters = np.unique(df['AUTHOR'])
print(f'Number of Painters: {len(painters)}')
# Out:
# Number of Painters: 3166

# %%
Counter(df['AUTHOR'])
# Out:
# Counter({'GOGH, Vincent van': 291,
#          'REMBRANDT Harmenszoon van Rijn': 236,
#          'GIOTTO di Bondone': 224,
#          'RUBENS, Peter Paul': 187,
#          'TIZIANO Vecellio': 181,
#          'GRECO, El': 177,
#          'VERONESE, Paolo': 170,
#          'RAFFAELLO Sanzio': 169,
#          'TINTORETTO': 168,
#          'CRANACH, Lucas the Elder': 166,
#          'TIEPOLO, Giovanni Battista': 165,
#          'ANGELICO, Fra': 150,
#          'UNKNOWN MASTER, Italian': 150,
#          'MEMLING, Hans': 125,
#          'MICHELANGELO Buonarroti': 120,
#          'MANTEGNA, Andrea': 111,
#          'GOYA Y LUCIENTES, Francisco de': 100,
#          'BELLINI, Giovanni': 96,
#          'MONET, Claude': 92,
#          'BOTTICELLI, Sandro': 90,
#          'TOULOUSE-LAUTREC, Henri de': 89,
#          'WEYDEN, Rogier van der': 86,
#          'DUCCIO di Buoninsegna': 85,
#          'POUSSIN, Nicolas': 85,
#          'CARAVAGGIO': 84,
#          'LOTTO, Lorenzo': 84,
#          'GOZZOLI, Benozzo': 84,
#          'CANALETTO': 82,
#          'GAUGUIN, Paul': 81,
#          'HOLBEIN, Hans the Younger': 79,
#          'DÜRER, Albrecht': 79,
#          'GHIRLANDAIO, Domenico': 78,
#          'CÉZANNE, Paul': 76,
#          'PIERO DELLA FRANCESCA': 75,
#          'VELÁZQUEZ, Diego Rodriguez de Silva y': 73,
#          'GOSSART, Jan': 71,
#          'BOSCH, Hieronymus': 70,
#          'PERUGINO, Pietro': 68,
#          'UNKNOWN MASTER, German': 68,
#          'UNKNOWN MASTER, Flemish': 68,
#          'LIPPI, Fra Filippo': 67,
#          'DYCK, Sir Anthony van': 67,
#          'DEGAS, Edgar': 64,
#          'HALS, Frans': 63,
#          'SIMONE MARTINI': 59,
#          'SIGNORELLI, Luca': 59,
#          'MANET, Edouard': 57,
#          'CARRACCI, Annibale': 54,
#          'EYCK, Jan van': 54,
#          'GUARDI, Francesco': 53,
#          'BRONZINO, Agnolo': 53,
#          'COURBET, Gustave': 52,
#          'TIEPOLO, Giovanni Domenico': 50,
#          'CARPACCIO, Vittore': 48,
#          'LIPPI, Filippino': 48,
#          'RENOIR, Pierre-Auguste': 47,
#          'BRUEGHEL, Jan the Elder': 47,
#          'DAVID, Jacques-Louis': 47,
#          'GIORDANO, Luca': 46,
#          'GIULIO ROMANO': 46,
#          'BOUCHER, François': 46,
#          'RICCI, Sebastiano': 46,
#          'FRIEDRICH, Caspar David': 45,
#          'CLAUDE LORRAIN': 45,
#          'STEEN, Jan': 45,
#          'DELACROIX, Eug?ne': 44,
#          'DOMENICHINO': 44,
#          'RENI, Guido': 44,
#          'TENIERS, David the Younger': 42,
#          'FRAGONARD, Jean-Honoré': 42,
#          'GUERCINO': 42,
#          'VERMEER, Johannes': 41,
#          'RUISDAEL, Jacob Isaackszon van': 41,
#          'PINTURICCHIO': 40,
#          'MURILLO, Bartolomé Esteban': 40,
#          'ARCIMBOLDO, Giuseppe': 39,
#          'BRUEGEL, Pieter the Elder': 39,
#          'ANDREA DEL SARTO': 39,
#          'LORENZETTI, Pietro': 39,
#          'TERBORCH, Gerard': 38,
#          'CHARDIN, Jean-Baptiste-Siméon': 38,
#          'CORTONA, Pietro da': 37,
#          'MASOLINO da Panicale': 37,
#          'PONTORMO, Jacopo': 36,
#          'UCCELLO, Paolo': 36,
#          'GOYEN, Jan van': 34,
#          'WATTEAU, Jean-Antoine': 34,
#          'VASARI, Giorgio': 34,
#          'ANDREA DEL CASTAGNO': 34,
#          'ZURBARÁN, Francisco de': 34,
#          'LEONARDO da Vinci': 33,
#          'LORENZO Monaco': 33,
#          'SPINELLO ARETINO': 33,
#          'PALMA GIOVANE': 33,
#          'BOUTS, Dieric the Elder': 33,
#          'HOOCH, Pieter de': 32,
#          'RIBERA, Jusepe de': 32,
#          'DAVID, Gerard': 31,
#          'DOU, Gerrit': 30,
#          'LONGHI, Pietro': 30,
#          'VERNET, Claude-Joseph': 30,
#          'CORREGGIO': 29,
#          'BELLOTTO, Bernardo': 29,
#          'HONTHORST, Gerrit van': 29,
#          'JORDAENS, Jacob': 29,
#          'GREUZE, Jean-Baptiste': 29,
#          'MAES, Nicolaes': 29,
#          'ROMANESQUE PAINTER, Italian': 29,
#          'RUYSDAEL, Salomon van': 29,
#          'BECCAFUMI, Domenico': 29,
#          'SALVIATI, Cecchino del': 28,
#          'BRUEGHEL, Pieter the Younger': 28,
#          'GADDI, Taddeo': 28,
#          'SODOMA, Il': 28,
#          'GIORGIONE': 27,
#          'HEEM, Jan Davidsz. de': 27,
#          'TURA, Cosm?': 27,
#          'BALDUNG GRIEN, Hans': 27,
#          'SNYDERS, Frans': 27,
#          'KESSEL, Jan van, I': 27,
#          'DORIGNY, Louis': 27,
#          'VOUET, Simon': 26,
#          'MASSYS, Quentin': 26,
#          'GIOVANNI DI PAOLO': 25,
#          'STROZZI, Bernardo': 25,
#          'MASACCIO': 25,
#          'OSTADE, Adriaen Jansz. van': 25,
#          'CUYP, Aelbert': 25,
#          'BASSANO, Jacopo': 25,
#          'ROBERT, Hubert': 25,
#          'LUINI, Bernardino': 25,
#          'CRESPI, Giuseppe Maria': 24,
#          'CRIVELLI, Carlo': 24,
#          'PRETI, Mattia': 24,
#          'CARRIERA, Rosalba': 24,
#          'HOBBEMA, Meyndert': 23,
#          'DADDI, Bernardo': 23,
#          'ALTDORFER, Albrecht': 23,
#          'ROSA, Salvator': 23,
#          'INGRES, Jean-Auguste-Dominique': 23,
#          'UNKNOWN MASTER, French': 23,
#          'SOLIMENA, Francesco': 23,
#          'SEBASTIANO DEL PIOMBO': 22,
#          'JACOPO DI CIONE': 22,
#          'VELDE, Willem van de, the Younger': 22,
#          'MASTER of Flémalle': 22,
#          'WITTE, Emanuel de': 22,
#          'PISSARRO, Camille': 22,
#          'WITTEL, Caspar Andriaans van': 22,
#          'GENTILE DA FABRIANO': 22,
#          'PIERO DI COSIMO': 22,
#          'LANFRANCO, Giovanni': 22,
#          'REYNOLDS, Sir Joshua': 22,
#          'LORENZETTI, Ambrogio': 21,
#          'PANNINI, Giovanni Paolo': 21,
#          'CRANACH, Lucas the Younger': 21,
#          'VIVARINI, Bartolomeo': 21,
#          'PARMIGIANINO': 21,
#          'FERRARI, Gaudenzio': 21,
#          'GOES, Hugo van der': 21,
#          'ROMANESQUE PAINTER, French': 21,
#          'CIMA da Conegliano': 20,
#          'METSU, Gabriel': 20,
#          'PACHER, Michael': 20,
#          'WOUWERMAN, Philips': 20,
#          'SANO di Pietro': 20,
#          'CHAMPAIGNE, Philippe de': 20,
#          'PELLEGRINI, Giovanni Antonio': 20,
#          'DOSSI, Dosso': 20,
#          'CLAESZ., Pieter': 20,
#          'HEEMSKERCK, Maerten van': 20,
#          'LA TOUR, Georges de': 20,
#          'POZZO, Andrea': 19,
#          'JUAN DE FLANDES': 19,
#          'PIAZZETTA, Giovanni Battista': 19,
#          'GAINSBOROUGH, Thomas': 19,
#          'GIOVANNI DA MILANO': 19,
#          'GRÜNEWALD, Matthias': 19,
#          'VALENTIN DE BOULOGNE': 19,
#          'ROSSO FIORENTINO': 18,
#          'BATONI, Pompeo': 18,
#          'ZELOTTI, Giovanni Battista': 18,
#          'BERCHEM, Nicolaes': 18,
#          'ALBANI, Francesco': 18,
#          'PAOLO VENEZIANO': 18,
#          'MURA, Francesco de': 18,
#          'SEURAT, Georges': 18,
#          'MORETTO da Brescia': 18,
#          'GENTILESCHI, Orazio': 18,
#          'FRANCESCO DI GIORGIO MARTINI': 18,
#          'MARIOTTO DI NARDO': 18,
#          'LANCRET, Nicolas': 18,
#          'SASSETTA': 18,
#          'ALTICHIERO da Zevio': 18,
#          'VERNET, Horace': 18,
#          'UNKNOWN ICON PAINTER, Russian': 18,
#          'COSTA, Lorenzo the Elder': 17,
#          'NATTIER, Jean-Marc': 17,
#          'FOPPA, Vincenzo': 17,
#          'FONTANA, Lavinia': 17,
#          'CHRISTUS, Petrus': 17,
#          'FETTI, Domenico': 17,
#          'LIEVENS, Jan': 17,
#          'MEMMI, Lippo': 17,
#          'LE NAIN brothers': 17,
#          'MOMPER, Joos de': 17,
#          'UNKNOWN MASTER, Spanish': 17,
#          'TERBRUGGHEN, Hendrick': 17,
#          'MOLENAER, Jan Miense': 17,
#          'COROT, Jean-Baptiste Camille': 17,
#          'CESARI, Giuseppe': 17,
#          'UGOLINO DI NERIO': 17,
#          'FYT, Jan': 17,
#          'NEER, Aert van der': 16,
#          'FLINCK, Govert Teunisz.': 16,
#          'CIMABUE': 16,
#          'AELST, Willem van': 16,
#          'BORDONE, Paris': 16,
#          'SISLEY, Alfred': 16,
#          'GENTILESCHI, Artemisia': 16,
#          'SAVERY, Roelandt': 16,
#          'WRIGHT, Joseph': 16,
#          'POURBUS, Frans the Younger': 16,
#          'HEDA, Willem Claesz.': 16,
#          'CERUTI, Giacomo': 16,
#          'EECKHOUT, Gerbrand van den': 16,
#          'WEENIX, Jan': 16,
#          'BARTOLOMEO, Fra': 16,
#          'ALLORI, Alessandro': 16,
#          'LE BRUN, Charles': 16,
#          'LAWRENCE, Sir Thomas': 16,
#          'TURNER, Joseph Mallord William': 16,
#          'POTTER, Paulus': 16,
#          'CLEVE, Joos van': 16,
#          'MAGNASCO, Alessandro': 15,
#          'FRANCKEN, Frans II': 15,
#          'ANTONELLO da Messina': 15,
#          'HEYDEN, Jan van der': 15,
#          'AST, Balthasar van der': 15,
#          'MARATTI, Carlo': 15,
#          'PALMA VECCHIO': 15,
#          'FERENCZY, Károly': 15,
#          'MORONI, Giovanni Battista': 15,
#          'BAROCCI, Federico Fiori': 15,
#          'KEYSER, Thomas de': 15,
#          'FRANCIA, Francesco': 15,
#          'AERTSEN, Pieter': 15,
#          'LORENZO VENEZIANO': 15,
#          'VENNE, Adriaen Pietersz. van de': 15,
#          'TIBALDI, Pellegrino': 15,
#          'GUARDI, Gianantonio': 15,
#          'ORLEY, Bernaert van': 14,
#          'CARRACCI, Lodovico': 14,
#          'CONSTABLE, John': 14,
#          'GADDI, Agnolo': 14,
#          'ZAVATTARI, Franceschino': 14,
#          'BRAY, Jan de': 14,
#          'BRUEGHEL, Jan the Younger': 14,
#          'PATER, Jean Baptiste Joseph': 14,
#          'HAYEZ, Francesco': 14,
#          'POELENBURGH, Cornelis van': 14,
#          'GUIDO DA SIENA': 14,
#          'BERRUGUETE, Pedro': 14,
#          'COSSA, Francesco del': 14,
#          'VIGÉE-LEBRUN, Élisabeth': 14,
#          'BRIL, Paul': 14,
#          'ANDREA DA FIRENZE': 14,
#          'BOURDON, Sébastien': 14,
#          "GIUSTO de' Menabuoi": 14,
#          'EVERDINGEN, Caesar van': 14,
#          'ROMANESQUE PAINTER, German': 14,
#          'GEERTGEN tot Sint Jans': 13,
#          'BLOEMAERT, Abraham': 13,
#          'MENGS, Anton Raphael': 13,
#          'CORNELIS VAN HAARLEM': 13,
#          'MENZEL, Adolph von': 13,
#          'MIERIS, Frans van, the Elder': 13,
#          'DUJARDIN, Karel': 13,
#          'BACICCIO': 13,
#          'LA HIRE, Laurent de': 13,
#          'ELSHEIMER, Adam': 13,
#          'BROUWER, Adriaen': 13,
#          'GREBBER, Pieter de': 13,
#          'PATENIER, Joachim': 13,
#          'BERCKHEYDE, Gerrit Adriaensz.': 13,
#          'KALF, Willem': 13,
#          'OUDRY, Jean-Baptiste': 13,
#          'UNKNOWN MASTER, Netherlandish': 13,
#          'DOLCI, Carlo': 13,
#          'FALCONETTO, Giovanni Maria': 13,
#          'MOR VAN DASHORST, Anthonis': 13,
#          'LEYDEN, Lucas van': 13,
#          'MELOZZO DA FORLI': 12,
#          'MUNKÁCSY, Mihály': 12,
#          'CARLEVARIS, Luca': 12,
#          'BOL, Ferdinand': 12,
#          'BLECHEN, Karl': 12,
#          'MOILLON, Louise': 12,
#          'SCOREL, Jan van': 12,
#          'GÉRICAULT, Théodore': 12,
#          'LARGILLI?RE, Nicolas de': 12,
#          'BOILLY, Louis Léopold': 12,
#          'PITTONI, Giambattista': 12,
#          'BEUCKELAER, Joachim': 12,
#          'MARIESCHI, Michele': 12,
#          'MASTER of Moulins': 12,
#          'PORDENONE': 12,
#          "ROBERTI, Ercole de'": 12,
#          'BONIFACIO VERONESE': 12,
#          'RICCI, Marco': 12,
#          'RUYSCH, Rachel': 12,
#          'SUSTRIS, Lambert': 12,
#          'ASSELYN, Jan': 12,
#          'LAIRESSE, Gérard de': 11,
#          'GALIZIA, Fede': 11,
#          'MILLET, Jean-François': 11,
#          'SUSTERMANS, Justus': 11,
#          'BACCHIACCA': 11,
#          'HOOGSTRATEN, Samuel van': 11,
#          'LAZZARINI, Gregorio': 11,
#          'PALAMEDESZ., Anthonie': 11,
#          'SARACENI, Carlo': 11,
#          'CARRE?O DE MIRANDA, Juan': 11,
#          'WTEWAEL, Joachim': 11,
#          'GIRODET DE ROUCY-TRIOSON, Anne-Louis': 11,
#          'FASOLO, Giovanni Antonio': 11,
#          'COLLIER, Edwart': 11,
#          'PROCACCINI, Giulio Cesare': 11,
#          'VELDE, Esaias van de': 11,
#          'MIGNARD, Pierre': 11,
#          'NETSCHER, Caspar': 11,
#          'MASTER of the Legend of Saint Ursula (I)': 11,
#          'MORALES, Luis de': 11,
#          'BELLINI, Jacopo': 11,
#          'PERRONNEAU, Jean-Baptiste': 11,
#          'BEYEREN, Abraham van': 11,
#          'DOMENICO VENEZIANO': 11,
#          'PROVOST, Jan': 11,
#          'ROBUSTI, Domenico': 11,
#          'ANGELI, Giuseppe': 11,
#          'SAENREDAM, Pieter Jansz': 11,
#          'MIEREVELD, Michiel Jansz. van': 11,
#          'HELST, Bartholomeus van der': 11,
#          'BASSANO, Francesco': 11,
#          'CODDE, Pieter': 11,
#          'LINGELBACH, Johannes': 11,
#          'GRIMMER, Abel': 11,
#          'VLIEGER, Simon de': 11,
#          'GIAQUINTO, Corrado': 11,
#          'PILLEMENT, Jean-Baptiste': 10,
#          'TOORENVLIET, Jacob': 10,
#          'GHIRLANDAIO, Ridolfo': 10,
#          'WERFF, Adriaen van der': 10,
#          'BASCHENIS, Evaristo': 10,
#          'DOMENICO DI BARTOLO': 10,
#          'RIGAUD, Hyacinthe': 10,
#          'KONINCK, Philips': 10,
#          'RIPPL-RÓNAI, József': 10,
#          'LIEBERMANN, Max': 10,
#          'WEST, Benjamin': 10,
#          'HALS, Dirck': 10,
#          'HERLIN, Friedrich': 10,
#          'BACKHUYSEN, Ludolf': 10,
#          'BARTOLOMEO DI GIOVANNI': 10,
#          'UDEN, Lucas van': 10,
#          'LASTMAN, Pieter Pietersz.': 10,
#          'CASTIGLIONE, Giovanni Benedetto': 10,
#          'FRANCIABIGIO': 10,
#          'GHERARDI, Filippo': 10,
#          'MIERIS, Willem van': 10,
#          'MELÉNDEZ, Luis': 10,
#          'BRUYN, Barthel the Elder': 10,
#          'WALDMÜLLER, Fedinand Georg': 10,
#          'PAÁL, László': 10,
#          'JANNECK, Franz Christoph': 10,
#          'NOMÉ, François de': 10,
#          'VELDE, Adriaen van de': 10,
#          'LE SUEUR, Eustache': 10,
#          'HACKERT, Jacob Philipp': 10,
#          'CROSATO, Giovanni Battista': 10,
#          'BOSSCHAERT, Ambrosius the Elder': 10,
#          'ROMNEY, George': 10,
#          'SCHALCKEN, Godfried': 10,
#          'MAULBERTSCH, Franz Anton': 10,
#          'SALIMBENI, Lorenzo': 10,
#          'KAUFFMANN, Angelica': 10,
#          'BIJLERT, Jan van': 10,
#          'NARDO DI CIONE': 10,
#          'BORTOLONI, Mattia': 10,
#          'DESPORTES, Alexandre-François': 10,
#          'VINCKBOONS, David': 10,
#          'SOLARIO, Andrea': 10,
#          'TORRITI, Jacopo': 9,
#          'PUGET, Pierre': 9,
#          'BREKELENKAM, Quiringh van': 9,
#          'BASTIANI, Lazzaro': 9,
#          'MASTER of St Francis': 9,
#          'OCHTERVELT, Jacob': 9,
#          'GÉRARD, François': 9,
#          'CECCO DI PIETRO': 9,
#          'STOM, Matthias': 9,
#          'BALEN, Hendrick van': 9,
#          'VALDÉS LEAL, Juan de': 9,
#          'MOLA, Pier Francesco': 9,
#          'POLLAIUOLO, Piero del': 9,
#          'MASTER of the St. Bartholomew Altar': 9,
#          'VERSPRONCK, Jan Cornelisz': 9,
#          'FLEGEL, Georg': 9,
#          'VIVARINI, Antonio': 9,
#          'VRANCX, Sebastian': 9,
#          'FERRARI, Luca': 9,
#          'POST, Frans': 9,
#          'ARELLANO, Juan de': 9,
#          'FUSELI, John Henry': 9,
#          'HAMEN, Juan van der': 9,
#          'BICCI DI LORENZO': 9,
#          'GROS, Antoine-Jean': 9,
#          'LOCHNER, Stefan': 9,
#          'CAILLEBOTTE, Gustave': 9,
#          'LISS, Johann': 9,
#          'UNKNOWN ICON PAINTER, Greek': 9,
#          'PERINO DEL VAGA': 9,
#          'COLI, Giovanni': 9,
#          'CARNEVALE, Fra': 9,
#          'VLIET, Hendrick Cornelisz. van': 9,
#          'GOLTZIUS, Hendrick': 9,
#          'CAVALLINO, Bernardo': 9,
#          'BLOEMEN, Jan Frans van': 9,
#          'VIVARINI, Alvise': 9,
#          'LUCA DI TOMM?': 9,
#          'ZUCCHI, Jacopo': 9,
#          'GIOVANNI DA SAN GIOVANNI': 9,
#          "HONDECOETER, Melchior d'": 9,
#          'SZINYEI MERSE, Pál': 9,
#          'PEREDA, Antonio de': 9,
#          'STRIGEL, Bernhard': 9,
#          'AVERCAMP, Hendrick': 9,
#          'LA TOUR, Maurice Quentin de': 9,
#          'HEMESSEN, Jan Sanders van': 9,
#          'FURINI, Francesco': 9,
#          'CLOUET, François': 9,
#          'UNKNOWN MASTER, Hungarian': 9,
#          'PINO, Marco': 9,
#          'OSTADE, Isaack van': 9,
#          'CANO, Alonso': 9,
#          'JOLI, Antonio': 9,
#          'SAVOLDO, Giovanni Girolamo': 9,
#          'KRÜGER, Franz': 9,
#          'ANGUISSOLA, Sofonisba': 9,
#          'CASTELLO, Valerio': 9,
#          'VOS, Marten de': 9,
#          'BACKER, Jacob Adriaensz.': 9,
#          'BELLINI, Gentile': 9,
#          'LIBERI, Pietro': 9,
#          'MASO DI BANCO': 8,
#          'BOCCACCINO, Boccaccio': 8,
#          'URBANI, Andrea': 8,
#          'GHISLANDI, Giuseppe': 8,
#          'MARSEUS VAN SCHRIECK, Otto': 8,
#          'VOS, Cornelis de': 8,
#          'BERGOGNONE, Ambrogio': 8,
#          'UNKNOWN ICON PAINTER, Cretan': 8,
#          'VERMEYEN, Jan Cornelisz.': 8,
#          'PYNACKER, Adam': 8,
#          'SCHÄUFELEIN, Hans Leonhard': 8,
#          'JACOPO del SELLAIO': 8,
#          'REYMERSWAELE, Marinus van': 8,
#          'SANCHEZ COELLO, Alonso': 8,
#          'HASSAM, Childe': 8,
#          'COELLO, Claudio': 8,
#          'COECKE VAN AELST, Pieter': 8,
#          'BEAUMONT, Claudio Francesco': 8,
#          'MOLYN, Pieter de': 8,
#          'OOST, Jacob van, the Elder': 8,
#          'JONSON VAN CEULEN, Cornelius the Elder': 8,
#          'CAPPELLE, Jan van de': 8,
#          'HOGARTH, William': 8,
#          'AMERLING, Friedrich von': 8,
#          'BLES, Herri met de': 8,
#          'FABRITIUS, Carel': 8,
#          'ANTOLINEZ, José': 8,
#          'HEEM, Cornelis de': 8,
#          'SAFTLEVEN, Herman': 8,
#          'AMIGONI, Jacopo': 8,
#          'MOUCHERON, Frederick de': 8,
#          'WIT, Jacob de': 8,
#          'POURBUS, Pieter': 8,
#          'DAHL, Johan Christian Clausen': 8,
#          'TOURNIER, Nicolas': 8,
#          'DUCK, Jacob': 8,
#          'VERROCCHIO, Andrea del': 8,
#          'VALENCIENNES, Pierre-Henri de': 8,
#          'BRAMER, Leonaert': 8,
#          'PISANELLO': 8,
#          'LORENZO DI CREDI': 8,
#          'PIOLA, Domenico': 8,
#          'ISENBRANT, Adriaen': 8,
#          'BASSANO, Leandro': 8,
#          'BARTOLO DI FREDI': 8,
#          'CORNELISZ VAN OOSTSANEN, Jacob': 8,
#          'SUBLEYRAS, Pierre': 8,
#          'CORNEILLE DE LYON': 8,
#          'UNKNOWN MASTER, Dutch': 8,
#          'ADEMOLLO, Luigi': 8,
#          'STANZIONE, Massimo': 8,
#          'CSONTVÁRY KOSZTKA, Tivadar': 8,
#          'ZOFFANY, Johann': 8,
#          'SASSOFERRATO': 8,
#          'BOLTRAFFIO, Giovanni Antonio': 8,
#          'RÉGNIER, Nicolas': 8,
#          'MASTER of the Fontainebleau School': 8,
#          'DUGHET, Gaspard': 8,
#          'PESNE, Antoine': 8,
#          'CRESPI, Daniele': 8,
#          'BÖCKLIN, Arnold': 8,
#          'SCHEFFER, Ary': 7,
#          'LOUTHERBOURG, Philip Jacques de': 7,
#          'K?BKE, Christen': 7,
#          'CAMPI, Vincenzo': 7,
#          'BIDAULD, Jean-Joseph-Xavier': 7,
#          'OS, Jan van': 7,
#          'STIELER, Karl Joseph': 7,
#          'MULTSCHER, Hans': 7,
#          'HOREMANS, Jan Jozef II': 7,
#          'LIMOSIN, Léonard': 7,
#          'WYNANTS, Jan': 7,
#          'IVÁNYI GRÜNWALD, Béla': 7,
#          'LIOTARD, Étienne': 7,
#          'STUBBS, George': 7,
#          'CHASSÉRIAU, Théodore': 7,
#          'ROMANESQUE PAINTER, Catalan': 7,
#          'FLORIS, Frans': 7,
#          'NICCOL? DI PIETRO GERINI': 7,
#          'FÜGER, Friedrich Heinrich': 7,
#          'MASTER of the Life of the Virgin': 7,
#          'DROOCHSLOOT, Joost Cornelisz.': 7,
#          'SLINGELAND, Pieter Cornelisz. van': 7,
#          'CASSATT, Mary': 7,
#          'ZUCCARO, Taddeo': 7,
#          'FONTEBASSO, Francesco': 7,
#          'BOR, Paulus': 7,
#          'BERGAMASCO, Il': 7,
#          "BARBARI, Jacopo de'": 7,
#          'BOTTICINI, Francesco': 7,
#          'DAWE, George': 7,
#          'ROSSELLI, Cosimo': 7,
#          'THEOPHANES the Greek': 7,
#          'RUNGE, Philipp Otto': 7,
#          'GAROFALO': 7,
#          'MEYTENS, Martin van, II': 7,
#          'TASSI, Agostino': 7,
#          'ROMANINO, Girolamo': 7,
#          'BREENBERGH, Bartholomeus': 7,
#          'LELY, Sir Peter': 7,
#          'PERUZZI, Baldassare': 7,
#          'RAEBURN, Sir Henry': 7,
#          'ZUCCARELLI, Francesco': 7,
#          'VECCHIETTA': 7,
#          'BROEDERLAM, Melchior': 7,
#          'CONCA, Sebastiano': 7,
#          'NEER, Eglon van der': 7,
#          'OOSTEN, Izaac van': 7,
#          'COORTE, Adriaen': 7,
#          'MASTER Bertram': 7,
#          'SWEERTS, Michiel': 7,
#          'KEY, Adriaen Thomasz': 7,
#          'WILLAERTS, Adam': 7,
#          'SIBERECHTS, Jan': 7,
#          'MASTER of the Castello della Manta': 7,
#          'CIGOLI': 7,
#          'HUGUET, Jaume': 7,
#          'COLE, Thomas': 7,
#          'HAMMERSH?I, Vilhelm': 7,
#          'SON, Joris van': 7,
#          'VALCKENBORCH, Lucas van': 7,
#          'MASTER of the Osservanza': 7,
#          'CARPIONI, Giulio': 7,
#          'ALBERTINELLI, Mariotto': 7,
#          'ECKERSBERG, Christoffer Wilhelm': 7,
#          'PARET Y ALCAZÁR, Luis': 7,
#          'DUPLESSIS, Joseph-Siffred': 7,
#          'BALESTRA, Antonio': 7,
#          'MEULEN, Adam Frans van der': 7,
#          'VOLAIRE, Pierre-Jacques': 7,
#          'KOCH, Joseph Anton': 7,
#          "NEROCCIO DE' LANDI": 7,
#          'STOSKOPFF, Sébastien': 7,
#          'BENSON, Ambrosius': 7,
#          'GUILLAUMIN, Armand': 7,
#          'HUYSUM, Jan van': 7,
#          'DELEN, Dirck van': 7,
#          'BERMEJO, Bartolomé': 7,
#          'BRAMANTINO': 7,
#          'NEEFFS, Peeter the Elder': 7,
#          'DELAROCHE, Paul': 7,
#          'MATTEO di Giovanni': 7,
#          'NAGY BALOGH, János': 7,
#          'GIJSELS, Pieter': 7,
#          'BERNINI, Gian Lorenzo': 7,
#          'ORCAGNA': 7,
#          'GRIMMER, Jacob': 7,
#          "MENEGHELLO di Giovanni de' Canali": 7,
#          'PREVITALI, Andrea': 7,
#          'BEECHEY, Sir William': 6,
#          'TREVISANI, Francesco': 6,
#          'LEYSTER, Judith': 6,
#          'UTRECHT, Adriaen van': 6,
#          'WYCK, Jan': 6,
#          'BROCKY, Károly': 6,
#          'ZANDOMENEGHI, Federico': 6,
#          'CAIRO, Francesco del': 6,
#          'PESELLINO': 6,
#          'LONGHI, Alessandro': 6,
#          'DIZIANI, Gaspare': 6,
#          'DECAMPS, Alexandre Gabriel': 6,
#          'ROMBOUTS, Theodor': 6,
#          'HUET, Christophe': 6,
#          'BUGIARDINI, Giuliano': 6,
#          'PADOVANINO': 6,
#          'MASTER of the Borgo Crucifix': 6,
#          'SCHOOTEN, Floris Gerritsz. van': 6,
#          'SCHEDONI, Bartolomeo': 6,
#          'VICTORS, Jan': 6,
#          'MAZZIERE, Agnolo di Domenico': 6,
#          'WITZ, Konrad': 6,
#          'TISCHBEIN, Johann Friedrich August': 6,
#          'BEMBO, Benedetto': 6,
#          'ASPERTINI, Amico': 6,
#          'GHIRLANDAIO, Davide': 6,
#          'MONTAGNA, Bartolomeo': 6,
#          'WEENIX, Jan Baptist': 6,
#          'CERESA, Carlo': 6,
#          'MASTER of the Acts of Mercy': 6,
#          'WALKER, Robert': 6,
#          'SZÉKELY, Bertalan': 6,
#          'PICKENOY, Nicolaes Eliasz.': 6,
#          'BARABÁS, Miklós': 6,
#          'BOCCATI, Giovanni di Piermatteo': 6,
#          'HERRERA, Francisco de, the Elder': 6,
#          'BASAITI, Marco': 6,
#          'PLATZER, Johann Georg': 6,
#          'MANFREDI, Bartolomeo': 6,
#          "BIAGIO D'ANTONIO": 6,
#          'SCHNORR VON CAROLSFELD, Julius': 6,
#          'RAMSAY, Allan': 6,
#          "FRANCESCO D'ANTONIO DI BARTOLOMMEO": 6,
#          'FANTIN-LATOUR, Henri': 6,
#          'MEDNYÁNSZKY, László': 6,
#          'JUANES, Juan de': 6,
#          'LIGOZZI, Jacopo': 6,
#          "PIETRO DI GIOVANNI D'AMBROGIO": 6,
#          'BRAY, Salomon de': 6,
#          'TURCHI, Alessandro': 6,
#          'LICINIO, Bernardino': 6,
#          'MEMBERGER, Kaspar the Elder': 6,
#          'EVERDINGEN, Allaert van': 6,
#          'ENGEBRECHTSZ., Cornelis': 6,
#          'LISIEWSKA, Anna Dorothea': 6,
#          "PRUD'HON, Pierre-Paul": 6,
#          'TOEPUT, Lodewijk': 6,
#          'BARNABA DA MODENA': 6,
#          'CORINTH, Lovis': 6,
#          'BLANCHARD, Jacques': 6,
#          'BABUREN, Dirck van': 6,
#          'MASTER of the Castello Nativity': 6,
#          'SARGENT, John Singer': 6,
#          'SITTOW, Michel': 6,
#          'MIGNON, Abraham': 6,
#          'ZAIS, Giuseppe': 6,
#          'CRETI, Donato': 6,
#          'BIMBI, Bartolomeo': 6,
#          'BASSEN, Bartholomeus van': 6,
#          'MASTER of the Legend of Saint Lucy': 6,
#          'CRAESBEECK, Josse van': 6,
#          'MASTER of AB Monogram': 6,
#          'SERRES, Dominic': 6,
#          'JACOBELLO DEL FIORE': 6,
#          'DANCE-HOLLAND, Nathaniel': 6,
#          'POLLAIUOLO, Antonio del': 6,
#          'BALDOVINETTI, Alessio': 6,
#          'KINSOEN, François-Joseph': 6,
#          'MASSYS, Jan': 6,
#          'UNKNOWN MASTER, Bohemian': 6,
#          'TANZIO DA VARALLO': 6,
#          'BAMBINI, Nicol?': 6,
#          'GILPIN, Sawrey': 6,
#          'ROTARI, Pietro Antonio': 6,
#          'PENCZ, Georg': 6,
#          'TOCQUÉ, Louis': 6,
#          'CUYP, Benjamin Gerritsz.': 6,
#          'COLONNA, Angelo Michele': 6,
#          'STRIJ, Abraham van, I': 6,
#          'MAN, Cornelis de': 6,
#          'GIAMBONO, Michele': 6,
#          'FERRARI, Gregorio de': 6,
#          'SEGHERS, Daniel': 6,
#          'VROOM, Hendrick Cornelisz.': 6,
#          'PEYRON, Jean-François-Pierre': 5,
#          'POEL, Egbert van der': 5,
#          'SCHEGGIA': 5,
#          'MASTER of Female Half-lengths': 5,
#          'MASTER THEODERIC': 5,
#          'CAROLUS-DURAN': 5,
#          'BUYTEWECH, Willem Pietersz.': 5,
#          'GABBIANI, Anton Domenico': 5,
#          'SEROV, Valentin': 5,
#          'BRUEGHEL, Abraham': 5,
#          'PRIMATICCIO, Francesco': 5,
#          'LEGA, Silvestro': 5,
#          'LAMPI, Johann Baptist I': 5,
#          'MASTER of the Housebook': 5,
#          'FABER VON CREUZNACH, Conrad': 5,
#          'PALMEZZANO, Marco': 5,
#          'STRIJ, Jacob van': 5,
#          'GIAMPIETRINO': 5,
#          'DANLOUX, Henri-Pierre': 5,
#          'HOUCKGEEST, Gerard': 5,
#          'MALER, Hans': 5,
#          'ROTTMANN, Carl': 5,
#          'KRAFFT, Johann Peter': 5,
#          'STRANOVER, Tobias': 5,
#          'ROUSSEAU, Théodore': 5,
#          'LINARD, Jacques': 5,
#          'BOROVIKOVSKY, Vladimir Lukich': 5,
#          'PASSEROTTI, Bartolomeo': 5,
#          'TSAFOURIS, Nikolaos': 5,
#          'RAFFAELLINO DEL GARBO': 5,
#          'GÉRÔME, Jean-Léon': 5,
#          'SIGNAC, Paul': 5,
#          'ROTTMAYR, Johann Michael': 5,
#          'PREDIS, Ambrogio de': 5,
#          'HANNEMAN, Adriaen': 5,
#          'NUVOLONE, Carlo Francesco': 5,
#          'UNKNOWN MASTER, Catalan': 5,
#          'LORENZO DI NICCOL? DI MARTINO': 5,
#          'WARD, James': 5,
#          'GRAMATICA, Antiveduto': 5,
#          'CRAYER, Gaspard de': 5,
#          'ASSERETO, Gioachino': 5,
#          'SCARSELLINO': 5,
#          'KERSTING, Georg Friedrich': 5,
#          'TADDEO DI BARTOLO': 5,
#          'LUTTICHUIJS, Simon': 5,
#          'CARUS, Carl Gustav': 5,
#          'LINT, Hendrik Frans van': 5,
#          'FABRITIUS, Barent': 5,
#          'SCOTT, Samuel': 5,
#          'SOROLLA Y BASTIDA, Joaquín': 5,
#          'LOTH, Johann Karl': 5,
#          'GELDER, Aert de': 5,
#          'SIRANI, Elisabetta': 5,
#          'ANESI, Paolo': 5,
#          'CLOUET, Jean': 5,
#          'MOSTAERT, Jan': 5,
#          'STORCK, Abraham': 5,
#          'CAROSELLI, Angelo': 5,
#          'VERBRUGGEN, Gaspar Peeter the Younger': 5,
#          'CLEVE, Hendrick van III': 5,
#          'AMBERGER, Christoph': 5,
#          'SACCHI, Andrea': 5,
#          'RICHTER, Adrian Ludwig': 5,
#          'MASTER of Frankfurt': 5,
#          'GHEERAERTS, Marcus the Younger': 5,
#          'CATENA, Vincenzo': 5,
#          'COYPEL, Antoine': 5,
#          'POORTER, Willem de': 5,
#          'GANDOLFI, Gaetano': 5,
#          'JONGH, Ludolf de': 5,
#          'MOREELSE, Paulus': 5,
#          'MAINARDI, Bastiano': 5,
#          'JOOS van Wassenhove': 5,
#          'SCHMIDT, Martin Johann': 5,
#          'RAFFAËLLI, Jean-François': 5,
#          'TILBORGH, Gillis van': 5,
#          'LÓPEZ Y PORTA?A, Vicente': 5,
#          'PANTOJA DE LA CRUZ, Juan': 5,
#          'PEETERS, Bonaventura I': 5,
#          'CORTE, Gabriel de la': 5,
#          'MOLENAER, Klaes': 5,
#          "ABBATE, Niccol? dell'": 5,
#          'FERRARI, Defendente': 5,
#          'BEER, Jan de': 5,
#          'VIGNON, Claude': 5,
#          'GHERARDI, Cristofano': 5,
#          'FERG, Franz de Paula': 5,
#          'CARIANI, Giovanni': 5,
#          'MASTER of the Palazzo Venezia Madonna': 5,
#          'VITALE DA BOLOGNA': 5,
#          'VELDE, Willem van de, the Elder': 5,
#          'BORGIANNI, Orazio': 5,
#          'TROYON, Constant': 5,
#          'FATTORI, Giovanni': 5,
#          'PULIGO, Domenico': 5,
#          'MASTER of Saint Cecilia': 5,
#          'MASTER of Saint Veronica': 5,
#          'DAUMIER, Honoré': 5,
#          'BLOOT, Pieter de': 5,
#          'MONNOYER, Jean-Baptiste': 5,
#          'HOLLÓSY, Simon': 5,
#          'SCHINKEL, Karl Friedrich': 5,
#          'WILKIE, Sir David': 5,
#          'STEENWIJCK, Harmen': 5,
#          'TROY, Jean-François de': 5,
#          'RIZI, Francisco': 5,
#          'MARKÓ, Károly the Elder': 5,
#          'GIJSBRECHTS, Cornelis Norbertus': 5,
#          'BEMBO, Bonifazio': 5,
#          'MASTER of the Hartford Still-life': 5,
#          'SARTORIUS, Francis I': 5,
#          'KOETS, Roelof': 5,
#          'LOTZ, Károly': 5,
#          'SCHÖNFELD, Johann Heinrich': 5,
#          'VANNINI, Ottavio': 5,
#          'ANTONIAZZO ROMANO': 5,
#          'BROWN, Mather': 5,
#          'BAGLIONE, Giovanni': 5,
#          'VERKOLJE, Johannes I': 5,
#          'SWANEVELT, Herman van': 5,
#          'WINTERHALTER, Franz Xaver': 5,
#          'CAVALLINI, Pietro': 5,
#          'FOUQUET, Jean': 5,
#          'BERNARD, Émile': 5,
#          'GENGA, Girolamo': 5,
#          'WOOTTON, John': 5,
#          'KEIL, Bernhard': 5,
#          'CALVAERT, Denys': 5,
#          'BAZILLE, Jean-Frédéric': 5,
#          'PYNAS, Jacob Symonsz.': 5,
#          'JOUVENET, Jean-Baptiste': 5,
#          'DROLLING, Martin': 5,
#          'COXCIE, Michiel van': 5,
#          'SPADA, Lionello': 5,
#          'NAIVEU, Matthijs': 5,
#          'GUÉRIN, Pierre-Narcisse': 5,
#          'BURGKMAIR, Hans': 5,
#          'COPPO DI MARCOVALDO': 5,
#          'RAVESTEYN, Jan Antonisz. van': 5,
#          'MAZZOLINO, Ludovico': 5,
#          'DAEL, Jan Frans van': 5,
#          'ODEVAERE, Joseph-Denis': 5,
#          'VUILLARD, Édouard': 5,
#          'BOSSCHAERT, Jan-Baptist': 5,
#          'BARTOLOMEO VENETO': 5,
#          'CECCO DEL CARAVAGGIO': 5,
#          'NAPOLETANO, Filippo': 5,
#          'LOO, Jacob van': 5,
#          'ROUSSEAU, Henri': 5,
#          'BOONEN, Arnold': 5,
#          'BELLUCCI, Antonio': 5,
#          'COYPEL, Noel-Nicolas': 5,
#          'UNKNOWN MASTER, Swiss': 5,
#          'UNKNOWN MASTER, Austrian': 5,
#          'BILIVERT, Giovanni': 4,
#          'TISSOT, James': 4,
#          'KÖNIG, Johann': 4,
#          'BOLDINI, Giovanni': 4,
#          'MORISOT, Berthe': 4,
#          'MORAZZONE': 4,
#          'MANETTI, Rutilio': 4,
#          'PLEYDENWURFF, Hans': 4,
#          'LAGRENÉE, Louis-Jean-François': 4,
#          'RESTOUT, Jean II': 4,
#          'UNKNOWN MASTER, English': 4,
#          'FRANCESCHINI, Baldassarre': 4,
#          'LIBERALE da Verona': 4,
#          'BRAMANTE, Donato': 4,
#          'GIOVANNI DA RIMINI': 4,
#          'GRUBACS, Carlo': 4,
#          'ZOPPO, Marco': 4,
#          'THULDEN, Theodor van': 4,
#          'DEVIS, Arthur': 4,
#          'VERNET, Carle': 4,
#          "ARTHOIS, Jacques d'": 4,
#          'MASTER of Saint Gilles': 4,
#          'TOSINI, Michele': 4,
#          'SIGNORINI, Telemaco': 4,
#          "VECCHI, Giovanni de'": 4,
#          'DIJCK, Floris Claesz van': 4,
#          'LE PRINCE, Jean-Baptiste': 4,
#          'CIGNANI, Carlo': 4,
#          'MINDERHOUT, Hendrik van': 4,
#          'DELPY, Hippolyte-Camille': 4,
#          'BEERSTRATEN, Jan Abrahamsz.': 4,
#          'COTELLE, Jean II': 4,
#          'ROMANELLI, Giovanni Francesco': 4,
#          'FABBRINI, Giuseppe Antonio': 4,
#          'LEIBL, Wilhelm': 4,
#          'RODIN, Auguste': 4,
#          'DOSSI, Battista': 4,
#          'WERFF, Pieter van der': 4,
#          'WILDENS, Jan': 4,
#          'SPITZWEG, Carl': 4,
#          'GILLEMANS, Jan Pauwel the Younger': 4,
#          'TILLEMANS, Peter': 4,
#          'KEY, Willem': 4,
#          'HIEPES, Tomás': 4,
#          'WOLGEMUT, Michael': 4,
#          'PAUDISS, Christoph': 4,
#          'CONTE, Jacopino del': 4,
#          'BONINGTON, Richard Parkes': 4,
#          'FEUERBACH, Anselm Friedrich': 4,
#          'FRANCO, Battista': 4,
#          'MARIO DEI FIORI': 4,
#          'MELZI, Francesco': 4,
#          'TRAVERSI, Gaspare': 4,
#          'VEEN, Otto van': 4,
#          'MARTIN, John': 4,
#          'GUARANA, Jacopo': 4,
#          'STALBEMT, Adriaan van': 4,
#          'MAFFEI, Francesco': 4,
#          'TITO, Santi di': 4,
#          'SPAENDONCK, Gerard van': 4,
#          'HOPPNER, John': 4,
#          'SEITER, Daniel': 4,
#          'PIETERSZ., Pieter': 4,
#          'CASTILLO, Antonio del': 4,
#          'CASSANA, Niccol?': 4,
#          'FÉNYES, Adolf': 4,
#          'BONITO, Giuseppe': 4,
#          'TOMMASO DI CREDI': 4,
#          'PRENDERGAST, Maurice Brazil': 4,
#          'WIJCK, Thomas': 4,
#          'DIAZ DE LA PE?A, Narcisse Virgile': 4,
#          'CARACCIOLO, Giovanni Battista': 4,
#          'FERRI, Ciro': 4,
#          'STARNINA, Gherardo di Jacopo': 4,
#          'MEISSONIER, Jean-Louis-Ernest': 4,
#          'MALOUEL, Jean': 4,
#          'MICHAU, Théobald': 4,
#          'CONTI, Francesco': 4,
#          'REGNAULT, Jean-Baptiste': 4,
#          'MULIER, Pieter the Elder': 4,
#          'TITO, Tiberio di': 4,
#          'CLEVE, Marten van I': 4,
#          'COTES, Francis': 4,
#          'VIGNALI, Jacopo': 4,
#          'CAGNACCI, Guido': 4,
#          'PÉREZ, Bartolomé': 4,
#          'LAER, Pieter van': 4,
#          'VECELLIO, Francesco': 4,
#          'CAFFI, Ippolito': 4,
#          'HEINTZ, Joseph the Younger': 4,
#          'RENARD DE SAINT-ANDRÉ, Simon': 4,
#          'DUPRÉ, Julien': 4,
#          'JACOMETTO VENEZIANO': 4,
#          'BADALOCCHIO, Sisto': 4,
#          'BARBAULT, Jean': 4,
#          'BRUYN, Barthel the Younger': 4,
#          'CESARE da Sesto': 4,
#          'LUYCKX, Christiaen': 4,
#          'LOO, Carle van': 4,
#          'REPIN, Ilya Yefimovich': 4,
#          'MASTER FRANCKE': 4,
#          'LABILLE-GUIARD, Adélaide': 4,
#          'MANSUETI, Giovanni': 4,
#          'PONCE, Antonio': 4,
#          'DROST, Willem': 4,
#          'LEVITSKY, Dmitry Grigorevich': 4,
#          'CAPANNA, Puccio': 4,
#          'BUTI, Lodovico': 4,
#          'GONZÁLEZ Y SERRANO, Bartolomé': 4,
#          'CLEVELEY, John the Elder': 4,
#          'RYCKAERT, David the Younger': 4,
#          'MARON, Anton von': 4,
#          'PUCCIO DI SIMONE': 4,
#          'GIOVANNI DA UDINE': 4,
#          'CAMPROBÍN, Pedro de': 4,
#          'MASTER of the Blue Jeans': 4,
#          'PHILIPSEN, Theodor Esbern': 4,
#          'MASTER of the Isaac Stories': 4,
#          'LEF?VRE, Robert': 4,
#          'BEERT, Osias the Elder': 4,
#          'NIEULANDT, Adriaen van, the Younger': 4,
#          "OGGIONO, Marco d'": 4,
#          'BICCI DI NERI': 4,
#          'BOTH, Jan': 4,
#          'GÉRARD, Marguerite': 4,
#          'BÉRAUD, Jean': 4,
#          'RATGEB, Jörg': 4,
#          'JACOBSZ., Lambert': 4,
#          'MORE, Jacob': 4,
#          'MASTER THOMAS de Coloswar': 4,
#          'ROTTENHAMMER, Hans I': 4,
#          'STEVENS, Alfred': 4,
#          'ABBATI, Giuseppe': 4,
#          'MARMION, Simon': 4,
#          'SANTERRE, Jean-Baptiste': 4,
#          'GRANACCI, Francesco': 4,
#          'ANDREA DI BARTOLO': 4,
#          'PORCELLIS, Jan': 4,
#          'KROHG, Christian': 4,
#          'R?RBYE, Martinus': 4,
#          'VALLAYER-COSTER, Anne': 4,
#          'BOGDÁNY, Jakab': 4,
#          'KR?YER, Peter Severin': 4,
#          'SOREAU, Isaak': 4,
#          'SEGHERS, Hercules': 4,
#          'CANELLA, Giuseppe': 4,
#          'QUELLINUS, Artus I': 4,
#          'DANIELE da Volterra': 4,
#          ...})

# %%
print(f'Timeframes: {np.unique(df.TIMEFRAME)}')
print(f'Number of Timeframes: {len(np.unique(df.TIMEFRAME))}')
# Out:
# Timeframes: ['0751-0800' '0801-0850' '0851-0900' '0951-1000' '1001-1050' '1051-1100'
#  '1101-1150' '1151-1200' '1201-1250' '1251-1300' '1301-1350' '1351-1400'
#  '1401-1450' '1451-1500' '1501-1550' '1551-1600' '1601-1650' '1651-1700'
#  '1701-1750' '1751-1800' '1801-1850' '1851-1900']
# Number of Timeframes: 22

# %% [markdown]
# #### Exploring Style Predictions dataset

# %%
styles = pd.read_csv(r'.\\Data\\style_predictions.csv', index_col = 0)
styles.head()
# Out:
#                     Abstract_Expressionism  Action_painting  \
# 00803-predel2.jpg                -5.855052        -2.445264
# 00612-01assump.jpg               -7.036362        -1.541759
# 28746-peasant.jpg                -0.700046        -1.472309
# 15937-nude.jpg                    6.848784         3.081389
# 39067-5tasso21.jpg               -6.122620        -2.033544
#
#                     Analytical_Cubism  Art_Nouveau   Baroque  \
# 00803-predel2.jpg            4.569021    -3.352057  5.504667
# 00612-01assump.jpg           1.251932     0.891822  4.758474
# 28746-peasant.jpg           -0.545117    -1.318472  9.125407
# 15937-nude.jpg              -1.157369     4.409545 -4.106697
# 39067-5tasso21.jpg          -0.916582     4.969154  1.594321
#
#                     Color_Field_Painting  Contemporary_Realism    Cubism  \
# 00803-predel2.jpg              -4.261706             -3.373453  2.724554
# 00612-01assump.jpg             -4.825901             -1.799933 -1.886111
# 28746-peasant.jpg              -4.149126              0.640162 -0.042066
# 15937-nude.jpg                  1.904504              0.077659 -2.560646
# 39067-5tasso21.jpg             -3.764644             -0.794799 -1.057732
#
#                     Early_Renaissance  Expressionism  ...  \
# 00803-predel2.jpg           11.630469       0.091760  ...
# 00612-01assump.jpg           8.589615      -0.715831  ...
# 28746-peasant.jpg           -2.182846       4.366738  ...
# 15937-nude.jpg              -1.097748      -1.226942  ...
# 39067-5tasso21.jpg           5.888536      -4.822448  ...
#
#                     Northern_Renaissance  Pointillism   Pop_Art  \
# 00803-predel2.jpg               4.752926    -0.247803 -3.056488
# 00612-01assump.jpg             10.572582     0.132770 -2.682440
# 28746-peasant.jpg               2.170227    -1.427454 -0.489499
# 15937-nude.jpg                 -0.894047     4.960007  1.868661
# 39067-5tasso21.jpg             -2.165867    -0.887301 -3.565545
#
#                     Post_Impressionism   Realism    Rococo  Romanticism  \
# 00803-predel2.jpg            -3.320292 -5.757197 -0.441127    -3.617446
# 00612-01assump.jpg            0.290388 -4.065725 -0.436026     3.389025
# 28746-peasant.jpg            -3.205423  5.222207  2.195539    -1.380008
# 15937-nude.jpg               -1.260525 -3.829489 -2.618714    -1.757044
# 39067-5tasso21.jpg           -2.281056 -3.081818  3.813381     3.989535
#
#                     Symbolism  Synthetic_Cubism   Ukiyo_e
# 00803-predel2.jpg    0.297716         -0.216189  0.802261
# 00612-01assump.jpg   1.217571         -1.016447  1.816147
# 28746-peasant.jpg   -0.770149         -0.559620  0.070471
# 15937-nude.jpg       7.611616         -0.971115 -1.122009
# 39067-5tasso21.jpg   6.825279         -2.700673 -2.256572
#
# [5 rows x 27 columns]

# %%
authors = ['GOGH, Vincent van', 'MONET, Claude', 'GAUGUIN, Paul', 'MANET, Edouard',
           'RAFFAELLO Sanzio','REMBRANDT Harmenszoon van Rijn','EYCK, Jan van']
X = styles.iloc[:, :-1]
y = styles.iloc[:, -1]

# %%
def create_artist_dataset(X, y, artist): 
    artist_df = df[df['AUTHOR'] == artist]
    X_artist = X.loc[artist_df['IMAGE_FILE']]

    styles = X_artist.columns[:27]
    possible_values = X_artist.iloc[:, :27].values
    max_style_idx = np.argmax(possible_values, axis = 1)
    max_styles = [styles[i] for i in max_style_idx]

    X_artist['dominant_style'] = max_styles
    
    return X_artist

# %% [markdown]
# #### Determine dominant style characteristics for each artist for painters experiment

# %%
for i in authors: 
    tmp = create_artist_dataset(X, y, i)
    print("************")
    print(f"Painter = {i}")
    print(Counter(tmp['dominant_style']))
# Out:
# ************
# Painter = GOGH, Vincent van
# Counter({'Post_Impressionism': 164, 'Realism': 45, 'Expressionism': 23, 'Impressionism': 20, 'Symbolism': 8, 'Art_Nouveau': 8, 'Naive_Art_Primitivism': 7, 'Baroque': 5, 'Mannerism_Late_Renaissance': 4, 'Romanticism': 2, 'Northern_Renaissance': 1, 'Rococo': 1, 'Fauvism': 1, 'Cubism': 1, 'Pointillism': 1})
# ************
# Painter = MONET, Claude
# Counter({'Impressionism': 71, 'Realism': 8, 'Romanticism': 3, 'Post_Impressionism': 3, 'Cubism': 1, 'Art_Nouveau': 1, 'Pop_Art': 1, 'Rococo': 1, 'Symbolism': 1, 'Synthetic_Cubism': 1, 'Baroque': 1})
# ************
# Painter = GAUGUIN, Paul
# Counter({'Post_Impressionism': 42, 'Expressionism': 11, 'Impressionism': 6, 'Romanticism': 6, 'Symbolism': 6, 'Art_Nouveau': 4, 'Northern_Renaissance': 2, 'Pointillism': 1, 'Cubism': 1, 'Naive_Art_Primitivism': 1, 'Realism': 1})
# ************
# Painter = MANET, Edouard
# Counter({'Impressionism': 24, 'Realism': 22, 'Art_Nouveau': 3, 'Romanticism': 2, 'Symbolism': 2, 'New_Realism': 1, 'Baroque': 1, 'High_Renaissance': 1, 'Post_Impressionism': 1})
# ************
# Painter = RAFFAELLO Sanzio
# Counter({'High_Renaissance': 67, 'Early_Renaissance': 24, 'Northern_Renaissance': 23, 'Baroque': 19, 'Mannerism_Late_Renaissance': 14, 'Symbolism': 9, 'Romanticism': 7, 'Rococo': 3, 'Realism': 2, 'Art_Nouveau': 1})
# ************
# Painter = REMBRANDT Harmenszoon van Rijn
# Counter({'Baroque': 168, 'Romanticism': 31, 'Realism': 14, 'Mannerism_Late_Renaissance': 9, 'Rococo': 5, 'Northern_Renaissance': 3, 'High_Renaissance': 3, 'Symbolism': 3})
# ************
# Painter = EYCK, Jan van
# Counter({'Northern_Renaissance': 36, 'Early_Renaissance': 9, 'Romanticism': 4, 'Baroque': 2, 'Cubism': 1, 'Mannerism_Late_Renaissance': 1, 'Analytical_Cubism': 1})

# %%
style_types = list(styles.columns)
max_styles = []
df = df[df['IMAGE_FILE'].isin(styles.index)]
for i in list(df['IMAGE_FILE']): 
    tmp = styles[styles.index == i]
    max_style_idx = np.argmax(tmp)
    max_styles.append(style_types[max_style_idx])

df['Max_Style'] = max_styles
df
# Out:
#                IMAGE_FILE                                        DESCRIPTION  \
# 0       19873-1darmst.jpg  The Meyer or Darmstadt Madonna is the last, mo...
# 1      18759-guard301.jpg  Whereas Canaletto incorporates classically ins...
# 2      04589-temptati.jpg  In this painting the refinement of the colouri...
# 3          15104-magi.jpg  The left side of the painting was cut, origina...
# 4      36582-paolo_f1.jpg  The painting illustrates a famous episode from...
# ...                   ...                                                ...
# 19239  07228-canal515.jpg  This picture is a supreme example of a distinc...
# 19240  06294-fighting.jpg  Dutch realism was a matter not merely of imita...
# 19241  21607-mytholo1.jpg  Lauri's speciality was the ideal landscape wit...
# 19242  02815-bacchant.jpg  Augustin was a French miniaturist who revived ...
# 19243  35847-fishingb.jpg  Salomon van Ruysdael painted similar views sin...
#
#                                 AUTHOR  \
# 0            HOLBEIN, Hans the Younger
# 1                    GUARDI, Francesco
# 2                   BILIVERT, Giovanni
# 3               GEERTGEN tot Sint Jans
# 4                        SCHEFFER, Ary
# ...                                ...
# 19239                        CANALETTO
# 19240                 BROUWER, Adriaen
# 19241                   LAURI, Filippo
# 19242  AUGUSTIN, Jean-Baptiste-Jacques
# 19243            RUYSDAEL, Salomon van
#
#                                                    TITLE  \
# 0                                      Darmstadt Madonna
# 1                      Landscape with a Fisherman's Tent
# 2                   The Temptation of Charles and Ubalde
# 3                                  Adoration of the Magi
# 4      The Ghosts of Paolo and Francesca Appear to Da...
# ...                                                  ...
# 19239  Venice: The Grand Canal from Palazzo Flangini ...
# 19240                                  Peasants Fighting
# 19241                                   Venus and Adonis
# 19242                                        A Bacchante
# 19243                           Fishing Boats on a River
#
#                            TECHNIQUE                 DATE          TYPE  \
# 0      Oil on limewood, 147 x 102 cm  1526 and after 1528     religious
# 1          Oil on canvas, 49 x 77 cm              1770-75     landscape
# 2          Oil on copper, 37 x 28 cm              1629-30     religious
# 3                 Panel, 111 x 69 cm              1480-85     religious
# 4        Oil on canvas, 167 x 234 cm                 1835         other
# ...                              ...                  ...           ...
# 19239      Oil on canvas, 47 x 78 cm               c.1738     landscape
# 19240        Oil on wood, 33 x 49 cm              1631-35         genre
# 19241      Oil on copper, 18 x 29 cm                1650s  mythological
# 19242          Ivory, diameter: 8 cm                 1799  mythological
# 19243        Oil on wood, 38 x 56 cm              1661-63     landscape
#
#               SCHOOL  TIMEFRAME             Max_Style
# 0             German  1501-1550  Northern_Renaissance
# 1            Italian  1751-1800               Baroque
# 2            Italian  1601-1650               Baroque
# 3      Netherlandish  1451-1500  Northern_Renaissance
# 4              Dutch  1801-1850               Baroque
# ...              ...        ...                   ...
# 19239        Italian  1701-1750               Baroque
# 19240        Flemish  1601-1650               Baroque
# 19241        Italian  1651-1700               Baroque
# 19242         French  1751-1800                Rococo
# 19243          Dutch  1601-1650               Realism
#
# [19244 rows x 10 columns]

# %% [markdown]
# #### Explore correlation between timeframe and style

# %%
for i in np.unique(df['TIMEFRAME']): 
    tmp = df[df.TIMEFRAME == i]
    print('***************************')
    print(i)
    print(Counter(tmp.Max_Style))
# Out:
# ***************************
# 0751-0800
# Counter({'Expressionism': 1, 'Post_Impressionism': 1})
# ***************************
# 0801-0850
# Counter({'Early_Renaissance': 3, 'High_Renaissance': 2})
# ***************************
# 0851-0900
# Counter({'Mannerism_Late_Renaissance': 1, 'Expressionism': 1, 'Impressionism': 1})
# ***************************
# 0951-1000
# Counter({'Impressionism': 2, 'Expressionism': 1, 'New_Realism': 1})
# ***************************
# 1001-1050
# Counter({'Early_Renaissance': 1})
# ***************************
# 1051-1100
# Counter({'Early_Renaissance': 15, 'Romanticism': 2, 'High_Renaissance': 2, 'Post_Impressionism': 2, 'Art_Nouveau': 2, 'Expressionism': 1, 'Symbolism': 1, 'Mannerism_Late_Renaissance': 1})
# ***************************
# 1101-1150
# Counter({'Early_Renaissance': 5, 'Symbolism': 2, 'Impressionism': 2, 'Expressionism': 1, 'Mannerism_Late_Renaissance': 1, 'Art_Nouveau': 1, 'Naive_Art_Primitivism': 1, 'Romanticism': 1})
# ***************************
# 1151-1200
# Counter({'Early_Renaissance': 15, 'Art_Nouveau': 3, 'Romanticism': 1, 'Ukiyo_e': 1, 'Cubism': 1})
# ***************************
# 1201-1250
# Counter({'Early_Renaissance': 8, 'Art_Nouveau': 8, 'Expressionism': 3, 'Naive_Art_Primitivism': 2, 'Romanticism': 1, 'Symbolism': 1, 'Ukiyo_e': 1, 'Pop_Art': 1, 'Post_Impressionism': 1, 'Mannerism_Late_Renaissance': 1, 'Northern_Renaissance': 1, 'Minimalism': 1})
# ***************************
# 1251-1300
# Counter({'Early_Renaissance': 71, 'Art_Nouveau': 12, 'Northern_Renaissance': 5, 'Symbolism': 5, 'Mannerism_Late_Renaissance': 5, 'High_Renaissance': 4, 'Romanticism': 4, 'Expressionism': 3, 'Impressionism': 3, 'Baroque': 2, 'Cubism': 1, 'New_Realism': 1})
# ***************************
# 1301-1350
# Counter({'Early_Renaissance': 492, 'Northern_Renaissance': 45, 'Symbolism': 26, 'Art_Nouveau': 16, 'Romanticism': 15, 'Mannerism_Late_Renaissance': 14, 'Baroque': 13, 'High_Renaissance': 12, 'Expressionism': 8, 'Post_Impressionism': 7, 'Impressionism': 6, 'Naive_Art_Primitivism': 3, 'New_Realism': 3, 'Cubism': 3, 'Realism': 2, 'Pop_Art': 2, 'Abstract_Expressionism': 1, 'Ukiyo_e': 1, 'Minimalism': 1})
# ***************************
# 1351-1400
# Counter({'Early_Renaissance': 229, 'Northern_Renaissance': 45, 'Mannerism_Late_Renaissance': 17, 'Symbolism': 15, 'Romanticism': 8, 'Art_Nouveau': 7, 'High_Renaissance': 6, 'Expressionism': 5, 'Baroque': 5, 'Post_Impressionism': 5, 'New_Realism': 2, 'Impressionism': 1, 'Abstract_Expressionism': 1, 'Ukiyo_e': 1})
# ***************************
# 1401-1450
# Counter({'Early_Renaissance': 506, 'Northern_Renaissance': 263, 'High_Renaissance': 34, 'Romanticism': 19, 'Mannerism_Late_Renaissance': 18, 'Symbolism': 17, 'Art_Nouveau': 15, 'Impressionism': 13, 'Expressionism': 11, 'Baroque': 10, 'Naive_Art_Primitivism': 9, 'New_Realism': 7, 'Post_Impressionism': 5, 'Realism': 3, 'Ukiyo_e': 2, 'Rococo': 2, 'Abstract_Expressionism': 1, 'Cubism': 1, 'Minimalism': 1, 'Analytical_Cubism': 1})
# ***************************
# 1451-1500
# Counter({'Early_Renaissance': 826, 'Northern_Renaissance': 625, 'High_Renaissance': 248, 'Mannerism_Late_Renaissance': 89, 'Baroque': 68, 'Romanticism': 58, 'Symbolism': 32, 'Impressionism': 23, 'Art_Nouveau': 23, 'Naive_Art_Primitivism': 14, 'Post_Impressionism': 13, 'Realism': 11, 'Expressionism': 8, 'Rococo': 7, 'New_Realism': 5, 'Pop_Art': 3, 'Cubism': 3, 'Ukiyo_e': 1, 'Minimalism': 1, 'Abstract_Expressionism': 1})
# ***************************
# 1501-1550
# Counter({'Northern_Renaissance': 760, 'High_Renaissance': 550, 'Baroque': 365, 'Mannerism_Late_Renaissance': 299, 'Early_Renaissance': 294, 'Romanticism': 88, 'Symbolism': 54, 'Realism': 42, 'Rococo': 30, 'Art_Nouveau': 18, 'Impressionism': 17, 'Expressionism': 15, 'Post_Impressionism': 14, 'New_Realism': 11, 'Naive_Art_Primitivism': 7, 'Ukiyo_e': 4, 'Cubism': 3, 'Pop_Art': 1, 'Analytical_Cubism': 1, 'Abstract_Expressionism': 1, 'Minimalism': 1, 'Pointillism': 1})
# ***************************
# 1551-1600
# Counter({'Baroque': 538, 'Mannerism_Late_Renaissance': 473, 'High_Renaissance': 129, 'Northern_Renaissance': 112, 'Early_Renaissance': 83, 'Romanticism': 72, 'Realism': 45, 'Rococo': 24, 'Impressionism': 23, 'Symbolism': 19, 'Expressionism': 17, 'Post_Impressionism': 14, 'Art_Nouveau': 13, 'New_Realism': 7, 'Cubism': 5, 'Ukiyo_e': 2, 'Pop_Art': 2, 'Naive_Art_Primitivism': 2, 'Minimalism': 2})
# ***************************
# 1601-1650
# Counter({'Baroque': 2188, 'Romanticism': 311, 'Realism': 234, 'Mannerism_Late_Renaissance': 184, 'Rococo': 168, 'High_Renaissance': 109, 'Early_Renaissance': 51, 'Northern_Renaissance': 43, 'Symbolism': 35, 'Impressionism': 23, 'Art_Nouveau': 15, 'Expressionism': 11, 'Naive_Art_Primitivism': 9, 'New_Realism': 7, 'Post_Impressionism': 5, 'Cubism': 4, 'Ukiyo_e': 3, 'Pop_Art': 3, 'Contemporary_Realism': 1})
# ***************************
# 1651-1700
# Counter({'Baroque': 1229, 'Romanticism': 280, 'Rococo': 168, 'Realism': 132, 'Mannerism_Late_Renaissance': 93, 'High_Renaissance': 39, 'Northern_Renaissance': 33, 'Symbolism': 19, 'Early_Renaissance': 18, 'Art_Nouveau': 15, 'Impressionism': 13, 'New_Realism': 12, 'Naive_Art_Primitivism': 10, 'Post_Impressionism': 6, 'Expressionism': 5, 'Pop_Art': 4, 'Synthetic_Cubism': 3, 'Ukiyo_e': 3, 'Cubism': 3, 'Abstract_Expressionism': 1, 'Minimalism': 1, 'Contemporary_Realism': 1})
# ***************************
# 1701-1750
# Counter({'Baroque': 510, 'Rococo': 475, 'Romanticism': 153, 'Realism': 83, 'Mannerism_Late_Renaissance': 74, 'High_Renaissance': 27, 'Symbolism': 23, 'Impressionism': 21, 'Art_Nouveau': 20, 'Early_Renaissance': 20, 'Northern_Renaissance': 11, 'New_Realism': 6, 'Post_Impressionism': 6, 'Expressionism': 5, 'Naive_Art_Primitivism': 3, 'Cubism': 2, 'Pop_Art': 2, 'Contemporary_Realism': 2, 'Pointillism': 1})
# ***************************
# 1751-1800
# Counter({'Rococo': 364, 'Baroque': 325, 'Romanticism': 239, 'Realism': 74, 'Mannerism_Late_Renaissance': 23, 'High_Renaissance': 16, 'Early_Renaissance': 16, 'Symbolism': 13, 'Impressionism': 11, 'Northern_Renaissance': 9, 'New_Realism': 6, 'Naive_Art_Primitivism': 6, 'Art_Nouveau': 5, 'Contemporary_Realism': 3, 'Expressionism': 2, 'Post_Impressionism': 2})
# ***************************
# 1801-1850
# Counter({'Romanticism': 431, 'Baroque': 211, 'Realism': 169, 'Rococo': 101, 'Mannerism_Late_Renaissance': 29, 'Northern_Renaissance': 25, 'Impressionism': 18, 'High_Renaissance': 16, 'Symbolism': 15, 'Early_Renaissance': 12, 'New_Realism': 6, 'Naive_Art_Primitivism': 6, 'Art_Nouveau': 6, 'Post_Impressionism': 3, 'Expressionism': 3, 'Contemporary_Realism': 1, 'Pop_Art': 1, 'Ukiyo_e': 1, 'Minimalism': 1, 'Cubism': 1})
# ***************************
# 1851-1900
# Counter({'Impressionism': 480, 'Realism': 393, 'Post_Impressionism': 315, 'Romanticism': 152, 'Expressionism': 71, 'Baroque': 66, 'Symbolism': 59, 'Pointillism': 35, 'Art_Nouveau': 34, 'Rococo': 27, 'Northern_Renaissance': 18, 'Naive_Art_Primitivism': 18, 'Cubism': 17, 'Mannerism_Late_Renaissance': 14, 'New_Realism': 10, 'Fauvism': 8, 'High_Renaissance': 7, 'Early_Renaissance': 7, 'Contemporary_Realism': 5, 'Abstract_Expressionism': 3, 'Ukiyo_e': 3, 'Pop_Art': 1, 'Minimalism': 1, 'Synthetic_Cubism': 1})
